# %% [markdown]
# # TTA: MODEL PRE-TRAINING AND DIAGNOSTICS

# %% [markdown]
# ## Set-up

# %%
# !git clone -b features/tta https://github.com/Type-Here/fdsml_federated_learning.git fdsml

# %%
# %cd fdsml

# %%
# !git pull

# %% [markdown]
# ## Dependencies

# %%
# !pip install -q phe gmpy2 flask-socketio python-socketio eventlet

# %% [markdown]
# ## Dataset

# %%
# !python datasets_prep/prepare_gtsrb.py --splits train

# %% [markdown]
# ## Training

# %%
# !python federated_grid_search.py grid_search_config_checkpoints.json

# %% [markdown]
# ## Results

# %%
# !ls -lh checkpoints_*/
# !cat checkpoints_*/*.json | head -60

# %% [markdown]
# # Diagnostics

# %% [markdown]
# ## Centralized Training (1 Client)

# %%
# !python federated_grid_search.py grid_search_config_diagnostic_central.json

# %%
# !cat csv_diagnostic_*/runs/*.csv

# %% [markdown]
# ## Federated Training Diagnotics

# %%
# !python federated_grid_search.py grid_search_config_diagnostic_federated.json

# %% [markdown]
# ## Data Augmentation Diagnostics

# %%
  # !python federated_grid_search.py grid_search_config_diagnostic_augmentation.json
